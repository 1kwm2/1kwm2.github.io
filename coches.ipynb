# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

# %%
ls static
# Out:
# export.csv  img/

# %%
df = pd.read_csv('static/export.csv')

# %%
df
# Out:
#                            Modelo      Motorizaci�n Categor�a N� de plazas  \
# 0      ALKE ATX 310 E plomo acido  El�ctricos puros        N1            2
# 1      ALKE ATX 320 E plomo acido  El�ctricos puros        N1            2
# 2      ALKE ATX 330 E plomo acido  El�ctricos puros        N1            2
# 3     ALKE ATX 330 ED plomo acido  El�ctricos puros        N1            4
# 4     ALKE ATX 330 EH plomo acido  El�ctricos puros        N1            2
# ...                           ...               ...       ...          ...
# 1036        ZERO MOTORCYCLES SRF   El�ctricos puros       L3e            2
# 1037        ZERO MOTORCYCLES SRS   El�ctricos puros       L3e            2
# 1038                  ZHIDOU d2 0  El�ctricos puros        M1            2
# 1039                 ZHIDOU d2s 1  El�ctricos puros        M1            2
# 1040      ZHIDOU d2s 5 ZD7150EV-A  El�ctricos puros       L7e            2
#
# ...
